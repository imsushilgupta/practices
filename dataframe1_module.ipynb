# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("revenue.csv", index_col="Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1,2,3,4])
s.sum()
# Out:
# 10

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis= 0)
rev.sum(axis= "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis=1)
rev.sum(axis= "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.head(8)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0

# %%
nba.Name
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
# 5      90.0
# 6      55.0
# 7      41.0
# 8      12.0
# 9      36.0
# 10      7.0
# 11      4.0
# 12     11.0
# 13     13.0
# 14     44.0
# 15     44.0
# 16     22.0
# 17     21.0
# 18     24.0
# 19      2.0
# 20     10.0
# 21      6.0
# 22      0.0
# 23     11.0
# 24      1.0
# 25     33.0
# 26     41.0
# 27     14.0
# 28     15.0
# 29     30.0
#        ...
# 428     8.0
# 429     5.0
# 430    23.0
# 431    17.0
# 432     4.0
# 433     9.0
# 434    35.0
# 435    11.0
# 436     0.0
# 437     3.0
# 438    44.0
# 439    24.0
# 440     2.0
# 441    21.0
# 442    33.0
# 443     3.0
# 444    10.0
# 445    11.0
# 446    15.0
# 447    27.0
# 448    20.0
# 449     5.0
# 450     2.0
# 451    23.0
# 452    41.0
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba["Name"]
nba["Weight"]
# Out:
# 0      180.0
# 1      235.0
# 2      205.0
# 3      185.0
# 4      231.0
# 5      240.0
# 6      235.0
# 7      238.0
# 8      190.0
# 9      220.0
# 10     260.0
# 11     185.0
# 12     220.0
# 13     215.0
# 14     253.0
# 15     216.0
# 16     190.0
# 17     200.0
# 18     220.0
# 19     200.0
# 20     208.0
# 21     219.0
# 22     175.0
# 23     275.0
# 24     200.0
# 25     220.0
# 26     237.0
# 27     248.0
# 28     205.0
# 29     221.0
#        ...
# 428    215.0
# 429    206.0
# 430    210.0
# 431    240.0
# 432    215.0
# 433    215.0
# 434    265.0
# 435    245.0
# 436    195.0
# 437    200.0
# 438    185.0
# 439    235.0
# 440    173.0
# 441    240.0
# 442    228.0
# 443    191.0
# 444    214.0
# 445    190.0
# 446    265.0
# 447    245.0
# 448    226.0
# 449    206.0
# 450    226.0
# 451    206.0
# 452    234.0
# 453    203.0
# 454    179.0
# 455    256.0
# 456    231.0
# 457      NaN
# Name: Weight, Length: 458, dtype: float64

# %%
type(nba["Name"])
# Out:
# pandas.core.series.Series

# %%
nba[["Name","Team"]]
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %%
select = ["Name","Team"]
nba[select]
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %%
nba["sport"] = "Basketball"
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba.insert(4, column = "sports", value = "Basketball")
nba.head(3)
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
#
#    Weight            College     Salary       sport
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
#
#    Weight            College     Salary       sport
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball

# %%
nba["Age"].add(5)
nba["Age"] + 5
nba["Salary"].sub(5000)
nba["Salary"] - 5000
nba["weight in kg"] = nba["Weight"].mul(0.45)
nba["Salary"].div(100)
# Out:
# 0       77303.37
# 1       67961.17
# 2            NaN
# 3       11486.40
# 4       50000.00
# 5      120000.00
# 6       11709.60
# 7       21651.60
# 8       18243.60
# 9       34310.40
# 10      25692.60
# 11      69128.69
# 12      34255.10
# 13      17498.40
# 14      26169.75
# 15      34255.10
# 16       8450.59
# 17      15000.00
# 18      13354.80
# 19      63000.00
# 20      15998.40
# 21       1342.15
# 22      15000.00
# 23     196890.00
# 24      11402.40
# 25       9472.76
# 26       9813.48
# 27       9472.76
# 28       9472.76
# 29     112359.55
#          ...
# 428     80428.95
# 429      6250.93
# 430      9472.76
# 431     69808.02
# 432     28940.59
# 433     60000.00
# 434     50160.00
# 435     30758.80
# 436     42362.87
# 437     25251.60
# 438      5250.93
# 439     14155.20
# 440     28549.40
# 441     26377.20
# 442     47750.00
# 443     26582.40
# 444     94634.84
# 445     37777.20
# 446    120000.00
# 447     11758.80
# 448    154095.70
# ...

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Charlotte Hornets         15
# Utah Jazz                 15
# Indiana Pacers            15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Brooklyn Nets             15
# Detroit Pistons           15
# Atlanta Hawks             15
# Toronto Raptors           15
# Dallas Mavericks          15
# Portland Trail Blazers    15
# Golden State Warriors     15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# San Antonio Spurs         15
# Washington Wizards        15
# Philadelphia 76ers        15
# Miami Heat                15
# Sacramento Kings          15
# Houston Rockets           15
# Denver Nuggets            15
# Phoenix Suns              15
# Boston Celtics            15
# Oklahoma City Thunder     15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
#
#    Weight            College     Salary       sport  weight in kg
# 0   180.0              Texas  7730337.0  Basketball         81.00
# 1   235.0          Marquette  6796117.0  Basketball        105.75
# 2   205.0  Boston University        NaN  Basketball         92.25

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position      sports   Age Height  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  Basketball  26.0    7-3
# 456   Jeff Withey  Utah Jazz    24.0        C  Basketball  26.0    7-0
# 457           NaN        NaN     NaN      NaN  Basketball   NaN    NaN
#
#      Weight College     Salary       sport  weight in kg
# 455   256.0     NaN  2900000.0  Basketball        115.20
# 456   231.0  Kansas   947276.0  Basketball        103.95
# 457     NaN     NaN        NaN  Basketball           NaN

# %%
nba.dropna()
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# 12               Evan Turner          Boston Celtics    11.0       SG
# 13               James Young          Boston Celtics    13.0       SG
# 14              Tyler Zeller          Boston Celtics    44.0        C
# ...

# %%
nba.dropna(how = "all")
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 2               John Holland          Boston Celtics    30.0       SG
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 4              Jonas Jerebko          Boston Celtics     8.0       PF
# 5               Amir Johnson          Boston Celtics    90.0       PF
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# ...

# %%
nba.dropna(axis= "columns")
# Out:
#          sports       sport
# 0    Basketball  Basketball
# 1    Basketball  Basketball
# 2    Basketball  Basketball
# 3    Basketball  Basketball
# 4    Basketball  Basketball
# 5    Basketball  Basketball
# 6    Basketball  Basketball
# 7    Basketball  Basketball
# 8    Basketball  Basketball
# 9    Basketball  Basketball
# 10   Basketball  Basketball
# 11   Basketball  Basketball
# 12   Basketball  Basketball
# 13   Basketball  Basketball
# 14   Basketball  Basketball
# 15   Basketball  Basketball
# 16   Basketball  Basketball
# 17   Basketball  Basketball
# 18   Basketball  Basketball
# 19   Basketball  Basketball
# 20   Basketball  Basketball
# 21   Basketball  Basketball
# 22   Basketball  Basketball
# 23   Basketball  Basketball
# 24   Basketball  Basketball
# 25   Basketball  Basketball
# 26   Basketball  Basketball
# 27   Basketball  Basketball
# 28   Basketball  Basketball
# 29   Basketball  Basketball
# ..          ...         ...
# 428  Basketball  Basketball
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
#
#    Weight            College     Salary       sport  weight in kg
# 0   180.0              Texas  7730337.0  Basketball         81.00
# 1   235.0          Marquette  6796117.0  Basketball        105.75
# 2   205.0  Boston University        NaN  Basketball         92.25

# %%
nba.dropna(subset=["Salary", "College"])
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# 12               Evan Turner          Boston Celtics    11.0       SG
# 13               James Young          Boston Celtics    13.0       SG
# 14              Tyler Zeller          Boston Celtics    44.0        C
# ...

# %%
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 2               John Holland          Boston Celtics    30.0       SG
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 4              Jonas Jerebko          Boston Celtics     8.0       PF
# 5               Amir Johnson          Boston Celtics    90.0       PF
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# ...

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  Basketball  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  Basketball  29.0   6-10
#
#    Weight            College     Salary       sport  weight in kg
# 0   180.0              Texas  7730337.0  Basketball         81.00
# 1   235.0          Marquette  6796117.0  Basketball        105.75
# 2   205.0  Boston University        0.0  Basketball         92.25
# 3   185.0      Georgia State  1148640.0  Basketball         83.25
# 4   231.0                NaN  5000000.0  Basketball        103.95

# %%
nba["College"].fillna("No College", inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  Basketball  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  Basketball  29.0   6-10
#
#    Weight            College     Salary       sport  weight in kg
# 0   180.0              Texas  7730337.0  Basketball         81.00
# 1   235.0          Marquette  6796117.0  Basketball        105.75
# 2   205.0  Boston University        0.0  Basketball         92.25
# 3   185.0      Georgia State  1148640.0  Basketball         83.25
# 4   231.0         No College  5000000.0  Basketball        103.95

# %%
nba.dropna(how = "all")
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 2               John Holland          Boston Celtics    30.0       SG
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 4              Jonas Jerebko          Boston Celtics     8.0       PF
# 5               Amir Johnson          Boston Celtics    90.0       PF
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# ...

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
# Name            457 non-null object
# Team            457 non-null object
# Number          457 non-null float64
# Position        457 non-null object
# sports          458 non-null object
# Age             457 non-null float64
# Height          457 non-null object
# Weight          457 non-null float64
# College         458 non-null object
# Salary          458 non-null int32
# sport           458 non-null object
# weight in kg    457 non-null float64
# dtypes: float64(4), int32(1), object(7)
# memory usage: 41.2+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")
nba["Number"] = nba["Number"].astype("int")
nba.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-1eee0eb659f5> in <module>()
# ----> 1 nba["Salary"] = nba["Salary"].astype("int")
#       2 nba["Number"] = nba["Number"].astype("int")
#       3 nba.head(3)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  Basketball  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  Basketball  29.0   6-10
#
#    Weight            College     Salary       sport  weight in kg
# 0   180.0              Texas  7730337.0  Basketball         81.00
# 1   235.0          Marquette  6796117.0  Basketball        105.75
# 2   205.0  Boston University        NaN  Basketball         92.25
# 3   185.0      Georgia State  1148640.0  Basketball         83.25
# 4   231.0                NaN  5000000.0  Basketball        103.95

# %%
nba["Number"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-e366babb634a> in <module>()
# ----> 1 nba["Number"].astype("int")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
nba["Age"] = nba["Age"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-b06fcc5fe43f> in <module>()
# ----> 1 nba["Age"] = nba["Age"].astype("int")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position      sports   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  Basketball  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  Basketball  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  Basketball  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  Basketball  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  Basketball  29.0   6-10
#
#    Weight            College   Salary       sport  weight in kg
# 0   180.0              Texas  7730337  Basketball         81.00
# 1   235.0          Marquette  6796117  Basketball        105.75
# 2   205.0  Boston University        0  Basketball         92.25
# 3   185.0      Georgia State  1148640  Basketball         83.25
# 4   231.0         No College  5000000  Basketball        103.95

# %%
nba["Number"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-e366babb634a> in <module>()
# ----> 1 nba["Number"].astype("int")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
nba["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba["Team"] = nba["Team"].astype("Category")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-f488218bb94a> in <module>()
# ----> 1 nba["Team"] = nba["Team"].astype("Category")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
nba

# %%
nba.sort_values("Name")

# %%
nba.head()

# %%
import pandas as pd

# %%
nba = pd.reas_csv("nba.csv")

# %%
nba

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values("Name", ascending = False)
# Out:
#                     Name                    Team  Number Position   Age  \
# 237        Zaza Pachulia        Dallas Mavericks    27.0        C  32.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 270       Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 385          Will Barton          Denver Nuggets     5.0       SF  25.0
# 233      Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 97        Wesley Johnson    Los Angeles Clippers    33.0       SF  28.0
# 17       Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 322       Walter Tavares           Atlanta Hawks    22.0        C  24.0
# ...

# %%
nba.sort_values("Salary", ascending = False ,na_position = "first")  #sort_index() as well
# Out:
#                        Name                    Team  Number Position   Age  \
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# ...

# %%
nba.sort_values(["Name", "Team"], ascending = ["True","False"])
# Out:
#                     Name                    Team  Number Position   Age  \
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# 330         Al Jefferson       Charlotte Hornets    25.0        C  31.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 368        Alan Anderson      Washington Wizards     6.0       SG  33.0
# 135        Alan Williams            Phoenix Suns    15.0        C  23.0
# 444           Alec Burks               Utah Jazz    10.0       SG  24.0
# 128             Alex Len            Phoenix Suns    21.0        C  22.0
# 273       Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# ...

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452
